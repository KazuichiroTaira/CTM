# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import datetime
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
DATA_FOLDER = 'LAM data'
FIG_FOLDER = 'fig'

os.makedirs(FIG_FOLDER, exist_ok=True)

# %%
data_file = os.path.join(DATA_FOLDER, 'lamraw_159_18_276.xlsx')
df = pd.read_excel(data_file)

df
# Out:
#        Measurement point  year  day  hour  minute  second  \
# 0                    159    18  276     0       0      10
# 1                    159    18  276     0       0      10
# 2                    159    18  276     0       0      13
# 3                    159    18  276     0       0      43
# 4                    159    18  276     0       0      49
# ...                  ...   ...  ...   ...     ...     ...
# 65961                159    18  276    23      59      22
# 65962                159    18  276    23      59      24
# 65963                159    18  276    23      59      46
# 65964                159    18  276    23      59      50
# 65965                159    18  276    23      59      51
#
#        hunderths of a second   vehicle lenght (m)  lane direction  \
# 0                         99  1980-05-01 00:00:00     2    Vantaa
# 1                         10                 4.00     1    Vantaa
# 2                         23  1940-03-01 00:00:00     2    Vantaa
# 3                         99                 3.00     4     Espoo
# 4                         15                 3.00     4     Espoo
# ...                      ...                  ...   ...       ...
# 65961                     81                25.00     1    Vantaa
# 65962                     99                 4.00     4     Espoo
# 65963                     25                 1.00     1    Vantaa
# 65964                     99  1940-03-01 00:00:00     4     Espoo
# 65965                      0                 0.60     1     Espoo
#
#        vehicle class  speed  If faulty, 1  Time (technical)  \
# 0                  1     85             0              1099
# 1                  1     82             0              1010
# 2                  1     79             0              1323
# 3                  1     79             0              4399
# 4                  1     70             0              4915
# ...              ...    ...           ...               ...
# 65961              5     78             0           8636281
# 65962              1     57             0           8636499
# 65963              1      1             1           8638625
# 65964              1     66             0           8639099
# 65965              1      9             1           8639100
#
#        time period (technical)  start (technical)
# 0                           -2                  0
# 1                           -2                  0
# 2                          199                  0
# 3                           -2                  0
# 4                          502                  0
# ...                        ...                ...
# 65961                     1642                  0
# 65962                      618                  0
# 65963                     2228                  0
# 65964                     2574                  0
# 65965                   920927                  0
#
# [65966 rows x 16 columns]

# %%
result = df.groupby(df(['hour'], ['direction']).size()
    print(result)
# Out:
#   File "<ipython-input-4-a75aa3dbfc0c>", line 2
#     print(result)
#     ^
# SyntaxError: invalid syntax

# %%
fig, ax = plt.subplots(figsize=(8, 7))
df['hour_str'] = df.hour.astype(str)
sns.histplot(df, x='hour_str', hue='direction', ax=ax) # kde=True
ax.set_xlabel('Hour')
ax.set_ylabel('Vehicles')
ax.set_title("159 - Espoo / Vantaa")
# Out:
# Text(0.5, 1.0, '159 - Espoo / Vantaa')
