# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import datetime
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
DATA_FOLDER = 'LAM data'
FIG_FOLDER = 'fig'

os.makedirs(FIG_FOLDER, exist_ok=True)

# %%
data_file = os.path.join(DATA_FOLDER, 'lamraw_128_18_276.xlsx')
df = pd.read_excel(data_file)

df
# Out:
#        Measurement point  year  day  hour  minute  second  \
# 0                    128    18  276     0       0      18
# 1                    128    18  276     0       0      20
# 2                    128    18  276     0       0      24
# 3                    128    18  276     0       0      28
# 4                    128    18  276     0       0      35
# ...                  ...   ...  ...   ...     ...     ...
# 91799                128    18  276    23      59      15
# 91800                128    18  276    23      59      17
# 91801                128    18  276    23      59      24
# 91802                128    18  276    23      59      54
# 91803                128    18  276    23      59      55
#
#        hunderths of a second   vehicle lenght (m)  lane direction  \
# 0                         99  2020-04-01 00:00:00     5     Espoo
# 1                         99  1940-03-01 00:00:00     5     Espoo
# 2                         53                17.20     5     Espoo
# 3                         99                 6.00     2    Vantaa
# 4                         48                24.20     2    Vantaa
# ...                      ...                  ...   ...       ...
# 91799                     17  2020-03-01 00:00:00     2    Vantaa
# 91800                     99  1940-03-01 00:00:00     5     Espoo
# 91801                     69  2020-11-01 00:00:00     1    Vantaa
# 91802                     99                16.60     2    Vantaa
# 91803                     99                 4.00     2    Vantaa
#
#        vehicle class  speed  If faulty, 1  Time (technical)  \
# 0                  1     83             0              1899
# 1                  1     83             0              2099
# 2                  5     81             0              2453
# 3                  1     79             0              2899
# 4                  5     83             0              3548
# ...              ...    ...           ...               ...
# 91799              1     81             0           8635517
# 91800              1     96             0           8635799
# 91801              2     79             0           8636469
# 91802              4     74             0           8639499
# 91803              1     77             0           8639599
#
#        time period (technical)  start (technical)
# 0                           -2                  0
# 1                          181                  0
# 2                          339                  0
# 3                           -2                  0
# 4                          621                  0
# ...                        ...                ...
# 91799                      300                  0
# 91800                     3484                  0
# 91801                    14555                  0
# 91802                     3967                  0
# 91803                       19                  0
#
# [91804 rows x 16 columns]

# %%
result = df.groupby(df(['hour'], ['direction']).size()
    print(result)
# Out:
#   File "<ipython-input-6-a75aa3dbfc0c>", line 2
#     print(result)
#     ^
# SyntaxError: invalid syntax

# %%
fig, ax = plt.subplots(figsize=(8, 7))
df['hour_str'] = df.hour.astype(str)
sns.histplot(df, x='hour_str', hue='direction', ax=ax) # kde=True
ax.set_xlabel('Hour')
ax.set_ylabel('Vehicles')
ax.set_title("128 - Espoo / Vantaa")
# Out:
# Text(0.5, 1.0, '128 - Espoo / Vantaa')
